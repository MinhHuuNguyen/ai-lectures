# %%
# !mkdir brain_tumor_mri_dataset_coco/
# !mkdir brain_tumor_mri_dataset_coco/images
# !mkdir brain_tumor_mri_dataset_coco/images/train
# !mkdir brain_tumor_mri_dataset_coco/images/val
# !mkdir brain_tumor_mri_dataset_coco/images/test
# !mkdir brain_tumor_mri_dataset_coco/labels
# !mkdir brain_tumor_mri_dataset_coco/labels/train
# !mkdir brain_tumor_mri_dataset_coco/labels/val

# %%
# !ls brain_tumor_mri_dataset_coco/
# Out:
# images labels

# %%
# !ls brain_tumor_mri_dataset_coco/images
# Out:
# test  train val

# %%
# !ls brain_tumor_mri_dataset_coco/labels
# Out:
# train val

# %%
# !cp brain_tumor_mri_dataset/test/* brain_tumor_mri_dataset_coco/images/test

# %% [markdown]
# # 1. Chuẩn bị dữ liệu ảnh

# %%
import pandas as pd
from tqdm import tqdm
from PIL import Image

from glob import glob
import json
import os

# %%
df = pd.read_csv('brain_tumor_mri_dataset/label.csv')
df = df.sample(frac=1)

# %%
train_df = df.iloc[:4000]
train_df
# Out:
#                                              image_name  label  xmin  ymin  \
# 2962  Cancer-948-_jpg.rf.262d9f0a368a4c0ea161022742f...  tumor   404   196
# 1897  Cancer-1350-_jpg.rf.2a6d0423cdf0a7c73f54529ef2...  tumor   364    75
# 304   Cancer-2166-_jpg.rf.773c85bd7680454833ac987a38...  tumor   232   433
# 1378  Cancer-1704-_jpg.rf.8fbab9d05e047eb0c97ed92499...  tumor   376   233
# 2806    y22_jpg.rf.ace2b5473b9585c613d4876f606068fb.jpg  tumor   330   160
# ...                                                 ...    ...   ...   ...
# 3183    y32_jpg.rf.2224beaadc79d48bbe4f42ffe4519a07.jpg  tumor   315   313
# 60    Cancer-1018-_jpg.rf.3282b28cd6de6df8d65e932906...  tumor   379   183
# 3620  Cancer-429-_jpg.rf.8976122285528aeaf68d3b218ef...  tumor   160   272
# 1799  Cancer-167-_jpg.rf.3429b70d20febd2a17b1241de89...  tumor   331   297
# 3831  Cancer-493-_jpg.rf.13e326751b4dc483490c9ef86c2...  tumor   325   156
#
#       xmax  ymax
# 2962   544   352
# 1897   520   246
# 304    331   527
# 1378   481   317
# 2806   500   407
# ...    ...   ...
# 3183   589   569
# 60     565   364
# 3620   215   305
# 1799   417   373
# 3831   452   313
#
# [4000 rows x 6 columns]

# %%
val_df = df.iloc[4000:]
val_df
# Out:
#                                              image_name   label  xmin  ymin  \
# 3688  Cancer-1780-_jpg.rf.c83ca135a9dce39d8f8aeb4cf0...   tumor   268   111
# 4018   y415_jpg.rf.818a934d356ddb93be295c3cc1503df4.jpg   tumor    62   152
# 3686  Cancer-1669-_jpg.rf.393eba57ea1e9466042e620369...   tumor   121   363
# 5268   y445_jpg.rf.2f02c16a91f6fc5d1f2bcaba6212bbf2.jpg   tumor   348   101
# 326   Cancer-1994-_jpg.rf.bf351c74cac57e1131d75022e7...   tumor   282   333
# ...                                                 ...     ...   ...   ...
# 3660   y403_jpg.rf.a2acc8e85ba4bccb597eedf736994d6f.jpg   tumor   360   411
# 681   Cancer-449-_jpg.rf.c1dbf3496d28891983f86d33300...   tumor   358   257
# 278   Not-Cancer-1507-_jpg.rf.9ab29e33e736312fe8e63e...  normal     0     0
# 798   Cancer-2189-_jpg.rf.aad14f2d9c5ae9638ed65c9cbe...   tumor   396   339
# 1612  Not-Cancer-347-_jpg.rf.7511d60d52861b79ae3b5f6...  normal     0     0
#
#       xmax  ymax
# 3688   558   398
# 4018   241   346
# 3686   346   583
# 5268   579   342
# 326    508   467
# ...    ...   ...
# 3660   444   543
# 681    458   352
# 278    640   640
# 798    508   463
# 1612   640   640
#
# [1870 rows x 6 columns]

# %%
for image_name in tqdm(train_df.image_name.to_list()):
    os.system(f'cp brain_tumor_mri_dataset/train/{image_name} brain_tumor_mri_dataset_coco/images/train/')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4000/4000 [00:17<00:00, 227.69it/s]

# %%
for image_name in tqdm(val_df.image_name.to_list()):
    os.system(f'cp brain_tumor_mri_dataset/train/{image_name} brain_tumor_mri_dataset_coco/images/val/')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1870/1870 [00:08<00:00, 233.09it/s]

# %% [markdown]
# # 2. Chuẩn bị label

# %%
train_df[['image_name', 'label', 'xmin', 'ymin', 'xmax', 'ymax']]
# Out:
#                                              image_name  label  xmin  ymin  \
# 2962  Cancer-948-_jpg.rf.262d9f0a368a4c0ea161022742f...  tumor   404   196
# 1897  Cancer-1350-_jpg.rf.2a6d0423cdf0a7c73f54529ef2...  tumor   364    75
# 304   Cancer-2166-_jpg.rf.773c85bd7680454833ac987a38...  tumor   232   433
# 1378  Cancer-1704-_jpg.rf.8fbab9d05e047eb0c97ed92499...  tumor   376   233
# 2806    y22_jpg.rf.ace2b5473b9585c613d4876f606068fb.jpg  tumor   330   160
# ...                                                 ...    ...   ...   ...
# 3183    y32_jpg.rf.2224beaadc79d48bbe4f42ffe4519a07.jpg  tumor   315   313
# 60    Cancer-1018-_jpg.rf.3282b28cd6de6df8d65e932906...  tumor   379   183
# 3620  Cancer-429-_jpg.rf.8976122285528aeaf68d3b218ef...  tumor   160   272
# 1799  Cancer-167-_jpg.rf.3429b70d20febd2a17b1241de89...  tumor   331   297
# 3831  Cancer-493-_jpg.rf.13e326751b4dc483490c9ef86c2...  tumor   325   156
#
#       xmax  ymax
# 2962   544   352
# 1897   520   246
# 304    331   527
# 1378   481   317
# 2806   500   407
# ...    ...   ...
# 3183   589   569
# 60     565   364
# 3620   215   305
# 1799   417   373
# 3831   452   313
#
# [4000 rows x 6 columns]

# %%
def prepare_label_txt(image_name, label, x1, y1, x2, y2, dataset_name):
    img = Image.open(f'brain_tumor_mri_dataset/train/{image_name}')
    img_w, img_h = img.size[0], img.size[1]
    # Convert from Absolute bounding box to Relative bounding box
    x = (x1 + x2) / 2 / img_w
    y = (y1 + y2) / 2 / img_h
    w = (x2 - x1) / img_w
    h = (y2 - y1) / img_h
    image_name = image_name.replace('.jpg', '.txt')
    with open(f'brain_tumor_mri_dataset_coco/labels/{dataset_name}/{image_name}', 'w') as file:
        if label == 'tumor':
            file.write(f'0 {x} {y} {w} {h}')
        else:
            pass

# %%
for _, row in tqdm(train_df.iterrows()):
    prepare_label_txt(
        row.image_name, row.label, row.xmin, row.ymin, row.xmax, row.ymax, 'train'
    )
# Out:
# 4000it [00:01, 3909.55it/s]

# %%
for _, row in tqdm(val_df.iterrows()):
    prepare_label_txt(
        row.image_name, row.label, row.xmin, row.ymin, row.xmax, row.ymax, 'val'
    )
# Out:
# 1870it [00:00, 4803.77it/s]

# %%
sample_name = os.listdir('./brain_tumor_mri_dataset_coco/labels/val/')[0]
with open(f'./brain_tumor_mri_dataset_coco/labels/val/{sample_name}', 'r') as file:
    lines = file.readlines()
lines
# Out:
# ['0 0.49453125 0.4703125 0.2015625 0.215625']

# %% [markdown]
# # 3. Chuẩn bị file txt đường dẫn

# %%
def create_txt_path_file(root_path, dataset_name):
    file_path_list = glob(os.path.join(root_path, dataset_name, '*'))
    file_path_list = [path.replace('brain_tumor_mri_dataset_coco', '.') + '\n' for path in file_path_list]
    with open(f'brain_tumor_mri_dataset_coco/{dataset_name}.txt', 'w') as file:
        file.writelines(file_path_list)

# %%
create_txt_path_file('brain_tumor_mri_dataset_coco/images/', 'val')

# %%
create_txt_path_file('brain_tumor_mri_dataset_coco/images/', 'train')

# %%
create_txt_path_file('brain_tumor_mri_dataset_coco/images/', 'test')

# %%
with open('brain_tumor_mri_dataset_coco/val.txt', 'r') as file:
    lines = file.readlines()
lines[:10]
# Out:
# ['./images/val/Not-Cancer-205-_jpg.rf.516a86e9b123d5e12000fe32483d2d26.jpg\n',
#  './images/val/Cancer-2295-_jpg.rf.81243ec5689cafedfdecf48ea855af05.jpg\n',
#  './images/val/Cancer-526-_jpg.rf.4f334b85e25c79129d9f624fd2033e55.jpg\n',
#  './images/val/Cancer-1989-_jpg.rf.81e1b3782103db3fec830402cce303b1.jpg\n',
#  './images/val/y303_jpg.rf.d200811b8aa1404800790214ab6dd840.jpg\n',
#  './images/val/Cancer-76-_jpg.rf.3adc33f4120893d05e4d0a2f8b34e68a.jpg\n',
#  './images/val/Not-Cancer-1618-_jpg.rf.813846badc3a430d9ba6bc8f0313205b.jpg\n',
#  './images/val/Cancer-835-_jpg.rf.3a3318e66898956b512becac2e3d82e0.jpg\n',
#  './images/val/Cancer-1348-_jpg.rf.34af6573fd9c0e084d5002147d54cf90.jpg\n',
#  './images/val/y384_jpg.rf.b4a8957a8d31d43d0a9aa5994867c37e.jpg\n']
