# %%
from glob import glob
import random
import ast

import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
ok_img_list = glob('lg_innotek_ok_ng_dataset/ng_ok_image_dataset/ok_img/*')
len(ok_img_list)
# Out:
# 1139

# %%
ng_img_list = glob('lg_innotek_ok_ng_dataset/ng_ok_image_dataset/ng_img/*')
len(ng_img_list)
# Out:
# 931

# %%
df = pd.read_csv('lg_innotek_ok_ng_dataset/ng_ok_image_dataset/label.csv')
df.region_shape_attributes = df.region_shape_attributes.apply(ast.literal_eval)
df.region_attributes = df.region_attributes.apply(ast.literal_eval)
df
# Out:
#                                    filename  file_size file_attributes  \
# 0            GCF3147A6B11CXC48_HistEq_R.jpg    1673732              {}
# 1            GCF3147AX2A1CXC41_HistEq_R.jpg    1671419              {}
# 2            GCF3147B8JV1CXC4N_HistEq_R.jpg    1670026              {}
# 3            GCF3147B8JV1CXC4N_HistEq_R.jpg    1670026              {}
# 4            GCF3147B8MM1CXC4M_HistEq_R.jpg    1670484              {}
# ..                                      ...        ...             ...
# 163  GCFGTC00070000007G+3089+Q_HistEq_R.jpg    1663547              {}
# 164  GCFGTD003DB000007G+3089+P_HistEq_R.jpg    1663643              {}
# 165  GCFGTD003DB000007G+3089+P_HistEq_R.jpg    1663643              {}
# 166  GCFGTD003W2000007G+3089+F_HistEq_R.jpg    1663160              {}
# 167  GCFGTD003W2000007G+3089+F_HistEq_R.jpg    1663160              {}
#
#      region_count  region_id  \
# 0               1          0
# 1               1          0
# 2               2          0
# 3               2          1
# 4               1          0
# ..            ...        ...
# 163             2          1
# 164             2          0
# 165             2          1
# 166             2          0
# 167             2          1
#
#                                region_shape_attributes  region_attributes
# 0    {'name': 'rect', 'x': 1943, 'y': 1264, 'width'...   {'Type': 'dust'}
# 1    {'name': 'rect', 'x': 7, 'y': 1303, 'width': 1...   {'Type': 'dust'}
# 2    {'name': 'rect', 'x': 5, 'y': 7, 'width': 109,...    {'Type': 'len'}
# 3    {'name': 'rect', 'x': 7, 'y': 1377, 'width': 1...    {'Type': 'len'}
# 4    {'name': 'rect', 'x': 86, 'y': 10, 'width': 10...   {'Type': 'dust'}
# ..                                                 ...                ...
# 163  {'name': 'rect', 'x': 1698, 'y': 1437, 'width'...  {'Type': 'shift'}
# 164  {'name': 'rect', 'x': 5, 'y': 1437, 'width': 6...  {'Type': 'shift'}
# 165  {'name': 'rect', 'x': 1730, 'y': 1439, 'width'...  {'Type': 'shift'}
# 166  {'name': 'rect', 'x': 2, 'y': 1441, 'width': 4...  {'Type': 'shift'}
# 167  {'name': 'rect', 'x': 1674, 'y': 1439, 'width'...  {'Type': 'shift'}
#
# [168 rows x 7 columns]

# %%
def draw_bbox_on_img(ng_img_list, df):
    while True:
        ng_img_path = random.choice(ng_img_list)
        ng_img_name = ng_img_path.split('/')[-1]
        item_df = df[df.filename == ng_img_name]
        if len(item_df) >= 1:
            break

    print(item_df)
    img = cv2.imread(ng_img_path, cv2.IMREAD_GRAYSCALE)

    item_bbox_list = item_df.region_shape_attributes.to_list()
    item_label_list = item_df.region_attributes.to_list()
    for bbox, label in zip(item_bbox_list, item_label_list):
        img = cv2.rectangle(
            img,
            (bbox['x'], bbox['y']),
            (bbox['x'] + bbox['width'], bbox['y'] + bbox['height']),
            color=(0, 0, 0),
            thickness=3
        )
        img = cv2.putText(
            img,
            label['Type'],
            (int(bbox['x'] + bbox['width'] / 3), bbox['y'] + bbox['height']),
            cv2.FONT_HERSHEY_SIMPLEX,
            1.2, (0, 0, 0), 3
        )
    return img

# %%
plt.figure(figsize=(15, 15))
plt.imshow(draw_bbox_on_img(ng_img_list, df))
plt.show()
# Out:
#                           filename  file_size file_attributes  region_count  \
# 88  GCF31474K061CXC3A_HistEq_R.jpg    1666828              {}             2
# 89  GCF31474K061CXC3A_HistEq_R.jpg    1666828              {}             2
#
#     region_id                            region_shape_attributes  \
# 88          0  {'name': 'rect', 'x': 12, 'y': 205, 'width': 1...
# 89          1  {'name': 'rect', 'x': 10, 'y': 7, 'width': 96,...
#
#    region_attributes
# 88  {'Type': 'dust'}
# 89   {'Type': 'len'}
