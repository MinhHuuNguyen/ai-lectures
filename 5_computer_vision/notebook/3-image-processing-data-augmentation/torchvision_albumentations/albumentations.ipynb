# %%
import matplotlib.pyplot as plt
import albumentations as A
import cv2

# %%
ori_img = cv2.imread('image.jpg')
ori_img = cv2.cvtColor(ori_img, cv2.COLOR_BGR2RGB)
ori_img, ori_img.shape
# Out:
# (array([[[114, 159, 214],
#          [114, 159, 214],
#          [114, 159, 214],
#          ...,
#          [138, 170, 208],
#          [138, 170, 208],
#          [138, 170, 208]],
#
#         [[114, 159, 214],
#          [114, 159, 214],
#          [114, 159, 214],
#          ...,
#          [138, 170, 208],
#          [138, 170, 208],
#          [138, 170, 208]],
#
#         [[114, 159, 214],
#          [114, 159, 214],
#          [114, 159, 214],
#          ...,
#          [138, 170, 208],
#          [138, 170, 208],
#          [138, 170, 208]],
#
#         ...,
#
#         [[119, 113, 101],
#          [123, 117, 105],
#          [124, 118, 106],
#          ...,
#          [ 34,  51,   0],
#          [ 33,  49,   0],
#          [ 35,  51,   4]],
#
#         [[114, 108,  96],
#          [126, 120, 108],
#          [124, 118, 106],
#          ...,
#          [ 34,  50,   3],
#          [ 40,  55,  12],
#          [ 42,  57,  14]],
#
#         [[109, 105,  93],
#          [110, 106,  94],
#          [111, 107,  96],
#          ...,
#          [ 32,  44,   4],
#          [ 42,  54,  14],
#          [ 57,  69,  29]]], shape=(625, 512, 3), dtype=uint8),
#  (625, 512, 3))

# %%
plt.imshow(ori_img)

# %% [markdown]
# # 1. Rotate

# %%
transform = A.Rotate(limit=15, p=1)
transform
# Out:
# Rotate(p=1.0, border_mode=0, crop_border=False, fill=0.0, fill_mask=0.0, interpolation=1, limit=(-15.0, 15.0), mask_interpolation=0, rotate_method='largest_box')

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 2. Flip

# %%
transform = A.HorizontalFlip(p=1)
transform
# Out:
# HorizontalFlip(p=1.0)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.VerticalFlip(p=1)
transform
# Out:
# VerticalFlip(p=1.0)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 3. Resize

# %%
transform = A.Resize(height=128, width=128)
transform
# Out:
# Resize(p=1.0, area_for_downscale=None, height=128, interpolation=1, mask_interpolation=0, width=128)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.Resize(height=128, width=256)
transform
# Out:
# Resize(p=1.0, area_for_downscale=None, height=128, interpolation=1, mask_interpolation=0, width=256)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 4. Crop

# %%
transform = A.RandomCrop(height=128, width=128)
transform
# Out:
# RandomCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=128, pad_if_needed=False, pad_position='center', width=128)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.RandomCrop(height=60, width=120)
transform
# Out:
# RandomCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=60, pad_if_needed=False, pad_position='center', width=120)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.CenterCrop(height=60, width=120)
transform
# Out:
# CenterCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=60, pad_if_needed=False, pad_position='center', width=120)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 5. Brightness, contrast

# %%
transform = A.RandomBrightnessContrast(contrast_limit=0.7, p=1)
transform
# Out:
# RandomBrightnessContrast(p=1.0, brightness_by_max=True, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.7, 0.7), ensure_safe_range=False)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.RandomBrightnessContrast(brightness_limit=0.7, p=1)
transform
# Out:
# RandomBrightnessContrast(p=1.0, brightness_by_max=True, brightness_limit=(-0.7, 0.7), contrast_limit=(-0.2, 0.2), ensure_safe_range=False)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.RandomBrightnessContrast(brightness_limit=0.7, contrast_limit=0.7, p=1)
transform
# Out:
# RandomBrightnessContrast(p=1.0, brightness_by_max=True, brightness_limit=(-0.7, 0.7), contrast_limit=(-0.7, 0.7), ensure_safe_range=False)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 6. Blur

# %%
transform = A.Blur(blur_limit=11, p=1)
transform
# Out:
# Blur(p=1.0, blur_limit=(3, 11))

# %%
plt.imshow(transform(image=ori_img)['image'])

# %% [markdown]
# # 7. Compose

# %%
transform = A.Compose([
    A.Rotate(limit=15, p=0.5),
    A.HorizontalFlip(p=0.5),
    A.RandomCrop(height=224, width=224),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5)
])
transform
# Out:
# Compose([
#   Rotate(p=0.5, border_mode=0, crop_border=False, fill=0.0, fill_mask=0.0, interpolation=1, limit=(-15.0, 15.0), mask_interpolation=0, rotate_method='largest_box'),
#   HorizontalFlip(p=0.5),
#   RandomCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=224, pad_if_needed=False, pad_position='center', width=224),
#   RandomBrightnessContrast(p=0.5, brightness_by_max=True, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), ensure_safe_range=False),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %%
plt.imshow(transform(image=ori_img)['image'])

# %%
transform = A.Compose([
    A.Rotate(limit=15, p=0.5),
    A.HorizontalFlip(p=0.5),
    A.RandomCrop(height=224, width=224),
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5),
    A.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
transform
# Out:
# Compose([
#   Rotate(p=0.5, border_mode=0, crop_border=False, fill=0.0, fill_mask=0.0, interpolation=1, limit=(-15.0, 15.0), mask_interpolation=0, rotate_method='largest_box'),
#   HorizontalFlip(p=0.5),
#   RandomCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=224, pad_if_needed=False, pad_position='center', width=224),
#   RandomBrightnessContrast(p=0.5, brightness_by_max=True, brightness_limit=(-0.2, 0.2), contrast_limit=(-0.2, 0.2), ensure_safe_range=False),
#   Normalize(p=1.0, max_pixel_value=255.0, mean=(0.485, 0.456, 0.406), normalization='standard', std=(0.229, 0.224, 0.225)),
# ], p=1.0, bbox_params=None, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %%
plt.imshow(transform(image=ori_img)['image'])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.117904..2.2914162].

# %% [markdown]
# # 8. Augmentations with bbox

# %%
bbox_ori_img = ori_img.copy()
bbox = [240, 7, 425, 560, 'tower']

# %%
bbox_ori_img = cv2.rectangle(
    img=bbox_ori_img,
    pt1=(bbox[0], bbox[1]),
    pt2=(bbox[2], bbox[3]),
    color=(0, 255, 0),
    thickness=1
)

# %%
plt.imshow(bbox_ori_img)

# %%
transform = A.Compose([
    A.RandomCrop(width=250, height=250),
    A.HorizontalFlip(p=0.5),
], bbox_params=A.BboxParams(format='pascal_voc'))
transform
# Out:
# Compose([
#   RandomCrop(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, height=250, pad_if_needed=False, pad_position='center', width=250),
#   HorizontalFlip(p=0.5),
# ], p=1.0, bbox_params={'format': 'pascal_voc', 'label_fields': None, 'min_area': 0.0, 'min_visibility': 0.0, 'min_width': 0.0, 'min_height': 0.0, 'check_each_transform': True, 'clip': False, 'max_accept_ratio': None}, keypoint_params=None, additional_targets={}, is_check_shapes=True)

# %%
transformed_data = transform(image=ori_img, bboxes=[bbox[:-1]])
transformed_data.keys()
# Out:
# dict_keys(['image', 'bboxes'])

# %%
transformed_img = transformed_data['image']
transformed_img
# Out:
# array([[[168, 164, 139],
#         [ 78,  73,  43],
#         [ 99,  90,  57],
#         ...,
#         [243, 217, 180],
#         [245, 217, 178],
#         [237, 213, 169]],
#
#        [[209, 201, 182],
#         [ 84,  71,  52],
#         [139, 124, 101],
#         ...,
#         [252, 224, 187],
#         [254, 225, 185],
#         [250, 223, 180]],
#
#        [[149, 137, 113],
#         [172, 156, 133],
#         [220, 202, 180],
#         ...,
#         [191, 161, 123],
#         [205, 176, 134],
#         [215, 186, 142]],
#
#        ...,
#
#        [[ 99,  92,  82],
#         [122, 115, 105],
#         [111, 104,  96],
#         ...,
#         [ 25,  38,  10],
#         [ 15,  27,   3],
#         [  0,   8,   0]],
#
#        [[103,  94,  85],
#         [116, 109,  99],
#         [128, 121, 111],
#         ...,
#         [ 25,  38,   8],
#         [ 14,  26,   2],
#         [ 14,  26,   4]],
#
#        [[115, 105,  95],
#         [ 95,  87,  76],
#         [ 97,  90,  80],
#         ...,
#         [ 33,  46,  16],
#         [ 18,  31,   5],
#         [ 25,  37,  13]]], shape=(250, 250, 3), dtype=uint8)

# %%
transformed_bboxes = transformed_data['bboxes']
transformed_bboxes
# Out:
# [[98.0, 0.0, 250.0, 191.00001728534698]]

# %%
bbox_transformed_img = cv2.rectangle(
    img=transformed_img,
    pt1=(int(transformed_bboxes[0][0]), int(transformed_bboxes[0][1])),
    pt2=(int(transformed_bboxes[0][2]), int(transformed_bboxes[0][3])),
    color=(0, 255, 0),
    thickness=1
)

# %%
plt.imshow(bbox_transformed_img)
