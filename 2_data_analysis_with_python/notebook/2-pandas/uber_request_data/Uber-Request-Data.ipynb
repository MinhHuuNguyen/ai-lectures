# %%
# %pip install pandas==2.2.3

# %%
import pandas as pd

# %%
df = pd.read_csv('Uber Request Data.csv')
df
# Out:
#       Request id Pickup point  Driver id             Status  \
# 0            619      Airport        1.0     Trip Completed
# 1            867      Airport        1.0     Trip Completed
# 2           1807         City        1.0     Trip Completed
# 3           2532      Airport        1.0     Trip Completed
# 4           3112         City        1.0     Trip Completed
# ...          ...          ...        ...                ...
# 6740        6745         City        NaN  No Cars Available
# 6741        6752      Airport        NaN  No Cars Available
# 6742        6751         City        NaN  No Cars Available
# 6743        6754         City        NaN  No Cars Available
# 6744        6753      Airport        NaN  No Cars Available
#
#         Request timestamp       Drop timestamp
# 0         11/7/2016 11:51      11/7/2016 13:00
# 1         11/7/2016 17:57      11/7/2016 18:47
# 2          12/7/2016 9:17       12/7/2016 9:58
# 3         12/7/2016 21:08      12/7/2016 22:03
# 4     13-07-2016 08:33:16  13-07-2016 09:25:47
# ...                   ...                  ...
# 6740  15-07-2016 23:49:03                  NaN
# 6741  15-07-2016 23:50:05                  NaN
# 6742  15-07-2016 23:52:06                  NaN
# 6743  15-07-2016 23:54:39                  NaN
# 6744  15-07-2016 23:55:03                  NaN
#
# [6745 rows x 6 columns]

# %%
# Câu 1: Load bộ dữ liệu Uber và kiểm tra bảng dữ liệu bằng cú pháp head, info
# Câu 2: Định dạng kiểu dữ liệu cột Request ID và Driver ID thành kiểu string
# Câu 3: Định dạng các giá trị nan trong cột Driver ID thành pd.NA? Sau đó dùng cú pháp dropna xóa đi các dòng có chứa giá trị NA?
# Câu 4: Kiểm tra định dạng dữ liệu của các cột Request timetsamp, Drop timestamp?
# Viết hàm và xử lý định dạng thời gian đồng nhất cho các cột này?
# Câu 5: Tạo thêm các cột RequestYear, RequestMonth, DropYear DropMonth bằng cú pháp datetime.year, datetime.month
# và định dạnh kiểu dữ liệu integer cho các cột DropYear, DropMonth
# Câu 6: Tạo thêm cột Duration tính khoảng cách thời gian giữa cột Request Timestamp và Drop timestamp,
# chuyển về dữ liệu dạng phút, định dạng kiểu dư liệu là số thực
# Câu 7: Dùng cú pháp value_counts đếm các giá trị trong các cột “Pickup Point” và cột “Status”
# Câu 8: Vẽ biểu đồ histogram quan sát phân bổ dữ liệu của cột Duration
# Câu 9: Vẽ biểu đồ Boxplot quan sát phân bổ dữ liệu của cột Duration

# %%
# Câu 1: Load bộ dữ liệu Uber và kiểm tra bảng dữ liệu bằng cú pháp head, info

# %%
df.head(10)
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# 5        3879      Airport        1.0  Trip Completed  13-07-2016 21:57:28
# 6        4270      Airport        1.0  Trip Completed  14-07-2016 06:15:32
# 7        5510      Airport        1.0  Trip Completed  15-07-2016 05:11:52
# 8        6248         City        1.0  Trip Completed  15-07-2016 17:57:27
# 9         267         City        2.0  Trip Completed       11/7/2016 6:46
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47
# 5  13-07-2016 22:28:59
# 6  14-07-2016 07:13:15
# 7  15-07-2016 06:07:52
# 8  15-07-2016 18:50:51
# 9       11/7/2016 7:25

# %%
df['Pickup point'].value_counts()
# Out:
# Pickup point
# City       3507
# Airport    3238
# Name: count, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Status
# Trip Completed       2831
# No Cars Available    2650
# Cancelled            1264
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB

# %%
# Câu 2: Định dạng kiểu dữ liệu cột Request ID và Driver ID thành kiểu string

# %%
df['Request id'] = df['Request id'].astype(str)

# %%
# df['Driver id'] = df['Driver id'].fillna(-99).astype(int).astype(str)

# %%
# df

# %%
# df.info()

# %%
# Câu 3: Định dạng các giá trị nan trong cột Driver ID thành pd.NA? Sau đó dùng cú pháp dropna xóa đi các dòng có chứa giá trị NA?

# %%
df['Driver id'] = df['Driver id'].fillna(pd.NA)

# %%
df = df.dropna(subset=['Driver id'])
df
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 0           619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1           867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2          1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3          2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4          3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# ...         ...          ...        ...             ...                  ...
# 4090       1641         City      299.0       Cancelled       12/7/2016 7:20
# 4091       4158         City      299.0       Cancelled  14-07-2016 05:03:10
# 4092       4164         City      299.0       Cancelled  14-07-2016 05:06:40
# 4093       4448         City      299.0       Cancelled  14-07-2016 08:30:59
# 4094       4225         City      300.0       Cancelled  14-07-2016 05:46:06
#
#            Drop timestamp
# 0         11/7/2016 13:00
# 1         11/7/2016 18:47
# 2          12/7/2016 9:58
# 3         12/7/2016 22:03
# 4     13-07-2016 09:25:47
# ...                   ...
# 4090                  NaN
# 4091                  NaN
# 4092                  NaN
# 4093                  NaN
# 4094                  NaN
#
# [4095 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4095 entries, 0 to 4094
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         4095 non-null   object
#  1   Pickup point       4095 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             4095 non-null   object
#  4   Request timestamp  4095 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 223.9+ KB

# %%
# Câu 4: Kiểm tra định dạng dữ liệu của các cột Request timetsamp, Drop timestamp?
# Viết hàm và xử lý định dạng thời gian đồng nhất cho các cột này?

# %%
df = df.dropna(subset=['Drop timestamp'])
df
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 0           619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1           867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2          1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3          2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4          3112         City        1.0  Trip Completed  13-07-2016 08:33:16
# ...         ...          ...        ...             ...                  ...
# 2826       1315      Airport      300.0  Trip Completed      11/7/2016 22:54
# 2827       2924         City      300.0  Trip Completed  13-07-2016 06:31:22
# 2828       3324      Airport      300.0  Trip Completed  13-07-2016 12:33:21
# 2829       3935      Airport      300.0  Trip Completed  13-07-2016 22:26:08
# 2830       5844      Airport      300.0  Trip Completed  15-07-2016 09:07:09
#
#            Drop timestamp
# 0         11/7/2016 13:00
# 1         11/7/2016 18:47
# 2          12/7/2016 9:58
# 3         12/7/2016 22:03
# 4     13-07-2016 09:25:47
# ...                   ...
# 2826      11/7/2016 23:35
# 2827  13-07-2016 07:20:52
# 2828  13-07-2016 13:16:03
# 2829  13-07-2016 23:43:13
# 2830  15-07-2016 09:56:07
#
# [2831 rows x 6 columns]

# %%
def process_timestamp(timestamp):
    day_month_year, hour_min_sec = timestamp.split(' ')
    if '/' in day_month_year:
        day, month, year = day_month_year.split('/')
    elif '-' in day_month_year:
        day, month, year = day_month_year.split('-')
    else:
        print('Error', day_month_year)

    day = day.zfill(2)
    month = month.zfill(2)
    year = year.zfill(4)

    hour_min_sec_list = hour_min_sec.split(':')
    if len(hour_min_sec_list) == 2:
        hour, minn = hour_min_sec_list
        sec = '00'
    elif len(hour_min_sec_list) == 3:
        hour, minn, sec = hour_min_sec_list
    else:
        print('Error', hour_min_sec)

    hour = hour.zfill(2)
    minn = minn.zfill(2)
    sec = sec.zfill(2)

    return f'{day}/{month}/{year} {hour}:{minn}:{sec}'

# %%
df['Request timestamp'] = df['Request timestamp'].apply(process_timestamp)
df['Drop timestamp'] = df['Drop timestamp'].apply(process_timestamp)
# Out:
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/1423367480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request timestamp'] = df['Request timestamp'].apply(process_timestamp)
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/1423367480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Drop timestamp'] = df['Drop timestamp'].apply(process_timestamp)

# %%
df
# Out:
#      Request id Pickup point  Driver id          Status    Request timestamp  \
# 0           619      Airport        1.0  Trip Completed  11/07/2016 11:51:00
# 1           867      Airport        1.0  Trip Completed  11/07/2016 17:57:00
# 2          1807         City        1.0  Trip Completed  12/07/2016 09:17:00
# 3          2532      Airport        1.0  Trip Completed  12/07/2016 21:08:00
# 4          3112         City        1.0  Trip Completed  13/07/2016 08:33:16
# ...         ...          ...        ...             ...                  ...
# 2826       1315      Airport      300.0  Trip Completed  11/07/2016 22:54:00
# 2827       2924         City      300.0  Trip Completed  13/07/2016 06:31:22
# 2828       3324      Airport      300.0  Trip Completed  13/07/2016 12:33:21
# 2829       3935      Airport      300.0  Trip Completed  13/07/2016 22:26:08
# 2830       5844      Airport      300.0  Trip Completed  15/07/2016 09:07:09
#
#            Drop timestamp
# 0     11/07/2016 13:00:00
# 1     11/07/2016 18:47:00
# 2     12/07/2016 09:58:00
# 3     12/07/2016 22:03:00
# 4     13/07/2016 09:25:47
# ...                   ...
# 2826  11/07/2016 23:35:00
# 2827  13/07/2016 07:20:52
# 2828  13/07/2016 13:16:03
# 2829  13/07/2016 23:43:13
# 2830  15/07/2016 09:56:07
#
# [2831 rows x 6 columns]

# %%
df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], format='%d/%m/%Y %H:%M:%S')
df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], format='%d/%m/%Y %H:%M:%S')
df
# Out:
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/3363095266.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Request timestamp'] = pd.to_datetime(df['Request timestamp'], format='%d/%m/%Y %H:%M:%S')
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/3363095266.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Drop timestamp'] = pd.to_datetime(df['Drop timestamp'], format='%d/%m/%Y %H:%M:%S')
#      Request id Pickup point  Driver id          Status   Request timestamp  \
# 0           619      Airport        1.0  Trip Completed 2016-07-11 11:51:00
# 1           867      Airport        1.0  Trip Completed 2016-07-11 17:57:00
# 2          1807         City        1.0  Trip Completed 2016-07-12 09:17:00
# 3          2532      Airport        1.0  Trip Completed 2016-07-12 21:08:00
# 4          3112         City        1.0  Trip Completed 2016-07-13 08:33:16
# ...         ...          ...        ...             ...                 ...
# 2826       1315      Airport      300.0  Trip Completed 2016-07-11 22:54:00
# 2827       2924         City      300.0  Trip Completed 2016-07-13 06:31:22
# 2828       3324      Airport      300.0  Trip Completed 2016-07-13 12:33:21
# 2829       3935      Airport      300.0  Trip Completed 2016-07-13 22:26:08
# 2830       5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
#           Drop timestamp
# 0    2016-07-11 13:00:00
# 1    2016-07-11 18:47:00
# 2    2016-07-12 09:58:00
# 3    2016-07-12 22:03:00
# 4    2016-07-13 09:25:47
# ...                  ...
# 2826 2016-07-11 23:35:00
# 2827 2016-07-13 07:20:52
# 2828 2016-07-13 13:16:03
# 2829 2016-07-13 23:43:13
# 2830 2016-07-15 09:56:07
#
# [2831 rows x 6 columns]

# %%
# Câu 5: Tạo thêm các cột RequestYear, RequestMonth, DropYear DropMonth bằng cú pháp datetime.year, datetime.month
# và định dạnh kiểu dữ liệu integer cho các cột DropYear, DropMonth

# %%
df['RequestYear'] = df['Request timestamp'].apply(lambda x: x.year)
df['RequestMonth'] = df['Request timestamp'].apply(lambda x: x.month)
df['DropYear'] = df['Drop timestamp'].apply(lambda x: x.year)
df['DropMonth'] = df['Drop timestamp'].apply(lambda x: x.month)
df
# Out:
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/2132409983.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RequestYear'] = df['Request timestamp'].apply(lambda x: x.year)
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/2132409983.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['RequestMonth'] = df['Request timestamp'].apply(lambda x: x.month)
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/2132409983.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DropYear'] = df['Drop timestamp'].apply(lambda x: x.year)
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/2132409983.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DropMonth'] = df['Drop timestamp'].apply(lambda x: x.month)
#      Request id Pickup point  Driver id          Status   Request timestamp  \
# 0           619      Airport        1.0  Trip Completed 2016-07-11 11:51:00
# 1           867      Airport        1.0  Trip Completed 2016-07-11 17:57:00
# 2          1807         City        1.0  Trip Completed 2016-07-12 09:17:00
# 3          2532      Airport        1.0  Trip Completed 2016-07-12 21:08:00
# 4          3112         City        1.0  Trip Completed 2016-07-13 08:33:16
# ...         ...          ...        ...             ...                 ...
# 2826       1315      Airport      300.0  Trip Completed 2016-07-11 22:54:00
# 2827       2924         City      300.0  Trip Completed 2016-07-13 06:31:22
# 2828       3324      Airport      300.0  Trip Completed 2016-07-13 12:33:21
# 2829       3935      Airport      300.0  Trip Completed 2016-07-13 22:26:08
# 2830       5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
#           Drop timestamp  RequestYear  RequestMonth  DropYear  DropMonth
# 0    2016-07-11 13:00:00         2016             7      2016          7
# 1    2016-07-11 18:47:00         2016             7      2016          7
# 2    2016-07-12 09:58:00         2016             7      2016          7
# 3    2016-07-12 22:03:00         2016             7      2016          7
# 4    2016-07-13 09:25:47         2016             7      2016          7
# ...                  ...          ...           ...       ...        ...
# 2826 2016-07-11 23:35:00         2016             7      2016          7
# 2827 2016-07-13 07:20:52         2016             7      2016          7
# 2828 2016-07-13 13:16:03         2016             7      2016          7
# 2829 2016-07-13 23:43:13         2016             7      2016          7
# 2830 2016-07-15 09:56:07         2016             7      2016          7
#
# [2831 rows x 10 columns]

# %%
# Câu 6: Tạo thêm cột Duration tính khoảng cách thời gian giữa cột Request Timestamp và Drop timestamp,
# chuyển về dữ liệu dạng phút, định dạng kiểu dư liệu là số thực

# %%
df['Duration'] = (df['Drop timestamp'] - df['Request timestamp']).dt.total_seconds() / 60.0
df
# Out:
# /var/folders/8_/m50_8s_942q571m12vh47_q80000gq/T/ipykernel_69272/480885588.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Duration'] = (df['Drop timestamp'] - df['Request timestamp']).dt.total_seconds() / 60.0
#      Request id Pickup point  Driver id          Status   Request timestamp  \
# 0           619      Airport        1.0  Trip Completed 2016-07-11 11:51:00
# 1           867      Airport        1.0  Trip Completed 2016-07-11 17:57:00
# 2          1807         City        1.0  Trip Completed 2016-07-12 09:17:00
# 3          2532      Airport        1.0  Trip Completed 2016-07-12 21:08:00
# 4          3112         City        1.0  Trip Completed 2016-07-13 08:33:16
# ...         ...          ...        ...             ...                 ...
# 2826       1315      Airport      300.0  Trip Completed 2016-07-11 22:54:00
# 2827       2924         City      300.0  Trip Completed 2016-07-13 06:31:22
# 2828       3324      Airport      300.0  Trip Completed 2016-07-13 12:33:21
# 2829       3935      Airport      300.0  Trip Completed 2016-07-13 22:26:08
# 2830       5844      Airport      300.0  Trip Completed 2016-07-15 09:07:09
#
#           Drop timestamp  RequestYear  RequestMonth  DropYear  DropMonth  \
# 0    2016-07-11 13:00:00         2016             7      2016          7
# 1    2016-07-11 18:47:00         2016             7      2016          7
# 2    2016-07-12 09:58:00         2016             7      2016          7
# 3    2016-07-12 22:03:00         2016             7      2016          7
# 4    2016-07-13 09:25:47         2016             7      2016          7
# ...                  ...          ...           ...       ...        ...
# 2826 2016-07-11 23:35:00         2016             7      2016          7
# 2827 2016-07-13 07:20:52         2016             7      2016          7
# 2828 2016-07-13 13:16:03         2016             7      2016          7
# 2829 2016-07-13 23:43:13         2016             7      2016          7
# 2830 2016-07-15 09:56:07         2016             7      2016          7
#
#        Duration
# 0     69.000000
# 1     50.000000
# 2     41.000000
# 3     55.000000
# 4     52.516667
# ...         ...
# 2826  41.000000
# 2827  49.500000
# 2828  42.700000
# 2829  77.083333
# 2830  48.966667
#
# [2831 rows x 11 columns]

# %%
# Câu 7: Dùng cú pháp value_counts đếm các giá trị trong các cột “Pickup Point” và cột “Status”

# %%
df['Pickup point'].value_counts()
# Out:
# Pickup point
# City       1504
# Airport    1327
# Name: count, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Status
# Trip Completed    2831
# Name: count, dtype: int64

# %%
# Câu 8: Vẽ biểu đồ histogram quan sát phân bổ dữ liệu của cột Duration

# %%
df['Duration'].hist()
# Out:
# <Axes: >

# %%
df['Duration'].hist().get_figure().savefig('histogram.png')

# %%
# Câu 9: Vẽ biểu đồ Boxplot quan sát phân bổ dữ liệu của cột Duration

# %%
df.boxplot(column='Duration')
# Out:
# <Axes: >

# %%
df.boxplot(column='Duration').get_figure().savefig('boxplot.png')
